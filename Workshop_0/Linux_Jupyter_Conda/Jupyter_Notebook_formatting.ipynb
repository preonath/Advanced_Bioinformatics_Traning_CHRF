# %% [markdown]
# # __Jupyter Notebook__

# %% [markdown]
# ![long-jupyter-notebook-logo.png](attachment:00221be6-7cc0-4d17-8ea4-d46b270116fc.png)

# %% [markdown]
# ## Installation

# %% [markdown]
# Follow this link to download __[JupyterLab Desktop](https://github.com/jupyterlab/jupyterlab-desktop)__ app:

# %% [markdown]
# #### Install __bash_kernel__

# %% [markdown]
# From you __terminal__ run the following code and __restart__ your JupyterLab

# %% [markdown]
# `pip install bash_kernel`
# `python -m bash_kernel.install`

# %% [markdown]
# ---

# %% [markdown]
# ## Important Keyboard Shortcuts

# %% [markdown]
# __NB: To use following shortcuts you have to exit from editing mode of a cell i.e., go outside of the cell__
#
# - To exit editing mode of a cell: __Esc__
# - Insert new cell below current cell: __b__
# - In new cell above current cell: __a__
# - Copy current cell: __c__
# - Paste current cell under current cell: __v__
# - Delete current cell: __dd__

# %% [markdown]
# ---

# %% [markdown]
# ## Heading and Title

# %% [markdown]
# # Title
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Normal size - smallest possible heading

# %% [markdown]
# ```
# # Title
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Normal size - smallest possible heading
# ```

# %% [markdown]
# __Shortcut Key__:
# - Title/Heading 1: 1
# - Heading 2: 2
# - Heading 3: 3
# - Heading 4: 4
# - Normal size: 5
# - Small size: 6

# %% [markdown]
# ---

# %% [markdown]
# ## Text Sahpe and Size

# %% [markdown]
# __Bold text__

# %% [markdown]
# ```
# __Bold text__
#
# **Bold text**
# ```

# %% [markdown]
# ---

# %% [markdown]
# _Italics_

# %% [markdown]
# ```
# _Italics_
# *Italics*
# ```

# %% [markdown]
# ---

# %% [markdown]
# `this is text for monospace font`

# %% [markdown]
# ```
# `this is text for monospace font`
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```
# Code Cell Style
# ```

# %% [markdown]
# ```
#     ```
#     Code Cell Style
#     ```
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## Links and Images

# %% [markdown]
# __External links__
#
# [Jupyter Notebook formatting](https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed)

# %% [markdown]
# ```
# External links
#
# [Jupyter Notebook formatting](https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed)
# ```

# %% [markdown]
# You can also bold the external link: __[Bold External Link](http://url)__

# %% [markdown]
# ```
# You can also bold the external link: __[Bold External Link](http://url)__
# ```

# %% [markdown]
# ***

# %% [markdown]
# #### __Insert Images in jupyter notebook__

# %% [markdown]
# __You can directly drag and drop an image in a markdown cell in jupyter notebook__

# %% [markdown]
# ![jupyter-notebook-logo.png](./images/jupyter-notebook-logo.png)

# %% [markdown]
# ```
# ![jupyter-notebook-logo.png](./images/jupyter-notebook-logo.png)
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## List

# %% [markdown]
# Numbered list can start with number. and a space. Eg: 1. text
#
# 1. This
# 2. Is
#     3. A
#     4. Numbered
# 5. List

# %% [markdown]
# Numbered list can start with number. and a space. Eg: 1. text
# ```
# 1. This
# 2. Is
#     3. A
#     4. Numbered
# 5. List
# ```

# %% [markdown]
# ---

# %% [markdown]
# Bulleted List:
# - list1
# - list2
#     - sublist1
#     - sublist2
# - list3
# - list4

# %% [markdown]
# Bulleted List:
# ```
# - list1
# - list2
#     - sublist1
#     - sublist2
# - list3
# - list4
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## Line Break

# %% [markdown]
# We can insert line break by using:
# 1. `<br>` tag
# 2. putting two __spaces__ at the end of the line

# %% [markdown]
# Line break<br>
# can be<br>
# done this<br>
# way
#
# This is without
# using the
# line break tag

# %% [markdown]
# ```
# Line break<br>
# can be<br>
# done this<br>
# way
#
# This is without
# using the
# line break tag
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## Color Fonts

# %% [markdown]
# <font color=blue>Blue Text</font>
# <font color=red>Red Text</font>
# <font color=green>__Bold Green Text__</font>
# <font color=pink>_Italic Pink Text_</font>
# <font color=yellow>Yellow Text</font>

# %% [markdown]
# ```
# <font color=blue>Blue Text</font>
# <font color=red>Red Text</font>
# <font color=green>__Bold Green Text__</font>
# <font color=pink>_Italic Pink Text_</font>
# <font color=yellow>Yellow Text</font>
# ```

# %% [markdown]
# -----

# %% [markdown]
# __Indentation Can be used as quote__
# > this is a sample text indentation
# >> This is double indentation
# >>> You can also use triple indentation

# %% [markdown]
# ```
# > this is a sample text indentation
# >> This is double indentation
# >>> You can also use triple indentation
# ```

# %% [markdown]
# ## Further Reading

# %% [markdown]
# [Advanced jupyter notebook formatting](https://towardsdatascience.com/bringing-the-best-out-of-jupyter-notebooks-for-data-science-f0871519ca29)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # __Conda__

# %% [markdown]
# ![Conda_logo.png](attachment:e0b826a3-3377-4de4-a331-d5cb5989b82f.png)

# %% [markdown]
# > __Don't forget to open this notebook in Bash Kernel__

# %% [markdown]
# ## Managing conda

# %% [markdown]
# ### 01: Verify that conda is installed and Check its version

# %% [markdown]
# ```
# conda --version
#
# # or,
# conda -V
#
# # More Details
# conda info
# ```

# %% [markdown]
# ### 02: Update conda to Current Newest Version

# %% [markdown]
# ```
# conda update conda -y
# ```

# %% [markdown]
# ## Managing Environments

# %% [markdown]
# ### 03: Create a new environment and install a package in it

# %% [markdown]
# ```
# conda create --name envname packageName -y
# ```

# %% [markdown]
# ### 04: Activate an Environment

# %% [markdown]
# ```
# conda activate envname
# ```

# %% [markdown]
# The active environment is also displayed in front/top of your prompt in (parentheses) or [brackets] like this:

# %% [markdown]
# ![terminal.png](attachment:1740b2b3-4b2b-4697-8357-85e6c0348af9.png)

# %% [markdown]
# ### 05: Deactivate Current Environment

# %% [markdown]
# ```
# conda deactivate
# ```

# %% [markdown]
# ### 06: List the Name of All Environments

# %% [markdown]
# ```
# conda info –-envs
#
# # or,
# conda env list
# ```

# %% [markdown]
# ### 07. Remove a conda Environment

# %% [markdown]
# > __Note: To remove a conda environment you must have to be outside of that environment.__

# %% [markdown]
# ```
# conda env remove --name envName -y
# ```

# %% [markdown]
# ## Managing Python

# %% [markdown]
# ### 07: Create a new environment named "snakes" that contains Python 3.9

# %% [markdown]
# ```
# conda create --name snakes python=3.9
# ```

# %% [markdown]
# ### 08: Check which Python is used by the current environment

# %% [markdown]
# ```
# which python
# ```

# %% [markdown]
# ### 09: Verify the version of Python in current environment

# %% [markdown]
# ```
# python --version
# ```

# %% [markdown]
# ## Managing Packages

# %% [markdown]
# ### 10: Install this package in the current environment

# %% [markdown]
# ```
# conda install packageName -y
# ```

# %% [markdown]
# ### 11: Remove a package in the current environment

# %% [markdown]
# ```
# conda remove packageName -y
# ```

# %% [markdown]
# ### 12: List all packages installed in the current environment

# %% [markdown]
# ```
# conda list
# ```
